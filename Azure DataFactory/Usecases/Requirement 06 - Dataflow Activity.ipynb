# %% [markdown]
# Requirement: DataFlow Activity to perform Transformations and Joins

# %% [markdown]
# # Create Dataflows
#
# First of all create Data flows from Author tab and create datasets for 2 Inputs and a Output

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Define all the components

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
