# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Create Linked Services for all the sources first – Blob, SQL](#toc1_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# Requirement : Lookup and copy from SQL Database to SQL Database

# %% [markdown]
# # <a id='toc1_'></a>[Create Linked Services for all the sources first – Blob, SQL](#toc0_)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Create Datasets – Lookup, Input, Output

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Create a Pipeline

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Configure this Lookup activity

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Configure Copy Data Activity

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Configure Fail Activity

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Configure Script Activity

# %% [markdown]
# ![image.png](attachment:image.png)
