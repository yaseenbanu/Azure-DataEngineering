# %% [markdown]
# # Monitor Tab
#
# Selec the Monitor Tab and select Pipeline Runs and select spectacle icon

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
