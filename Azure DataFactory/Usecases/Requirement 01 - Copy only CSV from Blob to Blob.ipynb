# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Creating Linked Services](#toc1_1_)
# - [Creating Datasets](#toc2_)
#   - [Input Dataset](#toc2_1_)
#   - [Output Dataset](#toc2_2_)
# - [Creating Pipeline](#toc3_)
#   - [Create a Pipeline](#toc3_1_)
#   - [Copy Activity Configurations](#toc3_2_)
#     - [General Tab](#toc3_2_1_)
#     - [Source Tab](#toc3_2_2_)
#     - [Sink Tab:](#toc3_2_3_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# Usecase: Copy only all CSV file from the input blob storage account to the output blob storage account.

# %% [markdown]
# ## <a id='toc1_1_'></a>[Creating Linked Services](#toc0_)

# %% [markdown]
# - Linked Service:
#     A Linked source is basically a connection which will connect to the data source
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # <a id='toc2_'></a>[Creating Datasets](#toc0_)

# %% [markdown]
# ## <a id='toc2_1_'></a>[Input Dataset](#toc0_)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <a id='toc2_2_'></a>[Output Dataset](#toc0_)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <a id='toc3_'></a>[Creating Pipeline](#toc0_)

# %% [markdown]
# ## <a id='toc3_1_'></a>[Create a Pipeline](#toc0_)
#
# Create a pipeline first and then select the activity – “Copy Data”

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <a id='toc3_2_'></a>[Copy Activity Configurations](#toc0_)

# %% [markdown]
# ### <a id='toc3_2_1_'></a>[General Tab](#toc0_)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### <a id='toc3_2_2_'></a>[Source Tab](#toc0_)
# (Here you need to specify the files which you want or wild card entries)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### <a id='toc3_2_3_'></a>[Sink Tab:](#toc0_)

# %% [markdown]
# ![image.png](attachment:image.png)
